# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1=np.linspace(0,10,20)

# %%
data1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
data2 = data1 **2

# %%
plt.subplots()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
type(my_fig)
# Out:
# matplotlib.figure.Figure

# %%
type(my_axes)
# Out:
# matplotlib.axes._axes.Axes

# %%
my_fig,my_axes = plt.subplots()
my_axes.plot(data1,data2,color="#00FFFF")
my_axes.plot(data2,data1,color="#FCC6BB")
plt.show()

# %%
(new_fig,new_axes)=plt.subplots()
new_axes.plot(data1,data1+2,color="blue",linewidth=1.0)
new_axes.plot(data1,data1+3,color="yellow",linewidth=2.0,linestyle="-.")
plt.show()

# %%
# scatter

# %%
plt.scatter(data1,data2,color="green")
plt.show()

# %%
#histogram

# %%
plt.hist(data1)
plt.show()

# %%
new_arr=np.random.randint(0,100,50)
new_arr
# Out:
# array([ 8, 56, 96, 54, 79, 62, 73, 43, 74, 60, 90, 20, 65, 36, 63,  4, 97,
#        50, 67, 51, 16, 97, 93, 22, 83,  8, 58, 48, 68,  3, 57, 51, 31, 84,
#        21, 28, 45, 10,  4, 15, 68,  1, 91,  0, 86, 64, 78, 84, 72, 92])

# %%
plt.hist(new_arr)
plt.show()

# %%
#box plot

# %%
plt.boxplot(new_arr)
plt.show()
