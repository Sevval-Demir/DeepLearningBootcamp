# %%
import pandas as pd

# %%
import numpy as np

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[-1.59247226, -1.41652579, -0.05894389],
#        [-0.85684782, -0.74124235, -0.68485641],
#        [-0.62896111, -0.83305815, -0.17652116],
#        [-0.37680655, -0.26773496,  1.09974627]])

# %%
#data_frame = pd.Series(data)
#Series tek boyutlu dataları tutar

# %%
data_frame = pd.DataFrame(data)

# %%
data_frame
# Out:
#           0         1         2
# 0 -1.592472 -1.416526 -0.058944
# 1 -0.856848 -0.741242 -0.684856
# 2 -0.628961 -0.833058 -0.176521
# 3 -0.376807 -0.267735  1.099746

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data_frame[0])
# Out:
# pandas.core.series.Series

# %%
new_df = pd.DataFrame(data,index = ["Sevval","Demir","Guzel","Dilan"],columns= ["Salary","Age","Seniority"])

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Sevval -1.592472 -1.416526  -0.058944
# Demir  -0.856848 -0.741242  -0.684856
# Guzel  -0.628961 -0.833058  -0.176521
# Dilan  -0.376807 -0.267735   1.099746

# %%
new_df["Age"]
# Out:
# Sevval   -1.416526
# Demir    -0.741242
# Guzel    -0.833058
# Dilan    -0.267735
# Name: Age, dtype: float64

# %%
new_df[["Age","Salary"]]
# Out:
#              Age    Salary
# Sevval -1.416526 -1.592472
# Demir  -0.741242 -0.856848
# Guzel  -0.833058 -0.628961
# Dilan  -0.267735 -0.376807

# %%
new_df.loc["Sevval"]
# Out:
# Salary      -1.592472
# Age         -1.416526
# Seniority   -0.058944
# Name: Sevval, dtype: float64

# %%
new_df.iloc[0]
# Out:
# Salary      -1.592472
# Age         -1.416526
# Seniority   -0.058944
# Name: Sevval, dtype: float64

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Sevval -1.592472 -1.416526  -0.058944
# Demir  -0.856848 -0.741242  -0.684856
# Guzel  -0.628961 -0.833058  -0.176521
# Dilan  -0.376807 -0.267735   1.099746

# %%
new_df.iloc[:,1]
# : bütün rowları seçeer sonraki sayıda hangi sütun olacağını söyler
# Out:
# Sevval   -1.416526
# Demir    -0.741242
# Guzel    -0.833058
# Dilan    -0.267735
# Name: Age, dtype: float64

# %%
new_df["Extra"] = 10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Sevval -1.592472 -1.416526  -0.058944     10
# Demir  -0.856848 -0.741242  -0.684856     10
# Guzel  -0.628961 -0.833058  -0.176521     10
# Dilan  -0.376807 -0.267735   1.099746     10

# %%
new_df.drop("Extra",axis = 1)
# Out:
#           Salary       Age  Seniority
# Sevval -1.592472 -1.416526  -0.058944
# Demir  -0.856848 -0.741242  -0.684856
# Guzel  -0.628961 -0.833058  -0.176521
# Dilan  -0.376807 -0.267735   1.099746

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Sevval -1.592472 -1.416526  -0.058944     10
# Demir  -0.856848 -0.741242  -0.684856     10
# Guzel  -0.628961 -0.833058  -0.176521     10
# Dilan  -0.376807 -0.267735   1.099746     10

# %%
new_df.drop("Extra",axis = 1,inplace =True)

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Sevval -1.592472 -1.416526  -0.058944
# Demir  -0.856848 -0.741242  -0.684856
# Guzel  -0.628961 -0.833058  -0.176521
# Dilan  -0.376807 -0.267735   1.099746

# %%
new_df["Mehmet"] = 10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Mehmet
# Sevval -1.592472 -1.416526  -0.058944      10
# Demir  -0.856848 -0.741242  -0.684856      10
# Guzel  -0.628961 -0.833058  -0.176521      10
# Dilan  -0.376807 -0.267735   1.099746      10

# %%
new_df.drop("Demir")
# Out:
#           Salary       Age  Seniority  Mehmet
# Sevval -1.592472 -1.416526  -0.058944      10
# Guzel  -0.628961 -0.833058  -0.176521      10
# Dilan  -0.376807 -0.267735   1.099746      10

# %%
new_df
# Out:
#           Salary       Age  Seniority  Mehmet
# Sevval -1.592472 -1.416526  -0.058944      10
# Demir  -0.856848 -0.741242  -0.684856      10
# Guzel  -0.628961 -0.833058  -0.176521      10
# Dilan  -0.376807 -0.267735   1.099746      10

# %%
#axis = 0 olursa satır , axis = 1 olduğu için sütun yönü
new_df.drop("Mehmet",axis = 1,inplace=True)

# %%
new_df.loc["Sevval"]
# Out:
# Salary      -1.592472
# Age         -1.416526
# Seniority   -0.058944
# Name: Sevval, dtype: float64

# %%
new_df.loc["Sevval"]["Salary"]
# Out:
# -1.5924722557743032

# %%
new_df.loc["Sevval","Salary"]
# Out:
# -1.5924722557743032

# %%
new_df.loc["Sevval","Salary"] = 150

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Sevval  150.000000 -1.416526  -0.058944
# Demir    -0.856848 -0.741242  -0.684856
# Guzel    -0.628961 -0.833058  -0.176521
# Dilan    -0.376807 -0.267735   1.099746

# %%
new_df > 0
# Out:
#         Salary    Age  Seniority
# Sevval    True  False      False
# Demir    False  False      False
# Guzel    False  False      False
# Dilan    False  False       True

# %%
boolean_frame = new_df > 0

# %%
new_df[boolean_frame]
# Out:
#         Salary  Age  Seniority
# Sevval   150.0  NaN        NaN
# Demir      NaN  NaN        NaN
# Guzel      NaN  NaN        NaN
# Dilan      NaN  NaN   1.099746

# %%
new_df[new_df > 0]
# Out:
#         Salary  Age  Seniority
# Sevval   150.0  NaN        NaN
# Demir      NaN  NaN        NaN
# Guzel      NaN  NaN        NaN
# Dilan      NaN  NaN   1.099746

# %%
new_df[new_df["Salary"] > 1]
# Out:
#         Salary       Age  Seniority
# Sevval   150.0 -1.416526  -0.058944

# %%
new_df.reset_index()
# Out:
#     index      Salary       Age  Seniority
# 0  Sevval  150.000000 -1.416526  -0.058944
# 1   Demir   -0.856848 -0.741242  -0.684856
# 2   Guzel   -0.628961 -0.833058  -0.176521
# 3   Dilan   -0.376807 -0.267735   1.099746

# %%
reset_frame = new_df.reset_index()

# %%
reset_frame
# Out:
#     index      Salary       Age  Seniority
# 0  Sevval  150.000000 -1.416526  -0.058944
# 1   Demir   -0.856848 -0.741242  -0.684856
# 2   Guzel   -0.628961 -0.833058  -0.176521
# 3   Dilan   -0.376807 -0.267735   1.099746

# %%
reset_frame.loc[0]
# Out:
# index          Sevval
# Salary          150.0
# Age         -1.416526
# Seniority   -0.058944
# Name: 0, dtype: object

# %%
reset_frame.iloc[0]
# Out:
# index          Sevval
# Salary          150.0
# Age         -1.416526
# Seniority   -0.058944
# Name: 0, dtype: object

# %%
new_indices = ["Sev","Dem","Guz","Dil"]

# %%
new_df["NewIndex"]= new_indices

# %%
new_df
# Out:
#             Salary       Age  Seniority NewIndex
# Sevval  150.000000 -1.416526  -0.058944      Sev
# Demir    -0.856848 -0.741242  -0.684856      Dem
# Guzel    -0.628961 -0.833058  -0.176521      Guz
# Dilan    -0.376807 -0.267735   1.099746      Dil

# %%
new_df.set_index("NewIndex",inplace=True)

# %%
new_df
# Out:
#               Salary       Age  Seniority
# NewIndex
# Sev       150.000000 -1.416526  -0.058944
# Dem        -0.856848 -0.741242  -0.684856
# Guz        -0.628961 -0.833058  -0.176521
# Dil        -0.376807 -0.267735   1.099746

# %%
new_df.loc["Sev"]
# Out:
# Salary       150.000000
# Age           -1.416526
# Seniority     -0.058944
# Name: Sev, dtype: float64

# %%
# multi index

# %%
first_index = ["Simpson","Simpson","Simpson","South Park","South Park","South Park"]

# %%
inner_index = ["Homer","Bart","Marge","Cartman","Kenny","Kyle"]

# %%
zipped_index = list(zip(first_index,inner_index))

# %%
zipped_index
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
zipped_index = pd.MultiIndex.from_tuples(zipped_index)

# %%
zipped_index
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
sample_values = np.ones((6,2))

# %%
big_df = pd.DataFrame(sample_values,index=zipped_index,columns=["Age","Salary"])

# %%
big_df
# Out:
#                     Age  Salary
# Simpson    Homer    1.0     1.0
#            Bart     1.0     1.0
#            Marge    1.0     1.0
# South Park Cartman  1.0     1.0
#            Kenny    1.0     1.0
#            Kyle     1.0     1.0

# %%
big_df["Age"]
# Out:
# Simpson     Homer      1.0
#             Bart       1.0
#             Marge      1.0
# South Park  Cartman    1.0
#             Kenny      1.0
#             Kyle       1.0
# Name: Age, dtype: float64

# %%
big_df.loc["Simpson"].loc["Homer"]
# Out:
# Age       1.0
# Salary    1.0
# Name: Homer, dtype: float64
